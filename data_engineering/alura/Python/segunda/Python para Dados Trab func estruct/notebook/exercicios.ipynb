# %%
#Exercicio 1
#!pip install matplotlib == 3.7.1

# %%
#exercicio 2
import numpy as np

#exercicio 3
from random import choice
lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]

listas = choice(lista)
listas
# Out:
# 54

# %%
#Exercicio 4
from random import randrange, sample

lista = []

for i in range(0,20):
    lista.append(randrange(100))

sample(lista, 5)
# Out:
# [43, 95, 25, 19, 23]

# %%
#Exercicio 5
from math import pow
n1 = int(input('Digite o primeiro número (potência): '))
n2 = int(input('Digite o segundo número (elevado): '))

resultado_pow = pow(n1,n2)
print(f'Resutlado: {resultado_pow}')
# Out:
# Resutlado: 8.0

# %%
#Exercicio 6
from random import randint, choice


sorteio = int(input('Digite o número de participantes: '))
sorteado = randint(1,sorteio)
print(f'O número sorteado foi: {sorteado}')

#ou

qtd = int(input('Digite o número de participantes: '))
lista = list(range(1, qtd + 1))

sorteado = choice(lista)
print(f'O número sorteado foi: {sorteado}')
# Out:
# O número sorteado foi: 52
# O número sorteado foi: 77

# %%
#Exercicio 7
from random import randint

name = input('Digite seu nome: ')
token = randint(1000, 9998)

print(f'Olá, {name}, o seu token de acesso é {token}! Seja bem-vindo(a)!')
# Out:
# Olá, akira, o seu token de acesso é 7250! Seja bem-vindo(a)!

# %%
#exercicio 8
from random import choice

frutas = ["maçã", "banana", "uva", "pêra", 
        "manga", "coco", "melancia", "mamão",
        "laranja", "abacaxi", "kiwi", "ameixa"]

salada_aleatoria = frutas[:3]

salada_aleatoria = choice(salada_aleatoria)
print(f"A salada de frutas surpresa : {salada_aleatoria}")
# Out:
# A salada de frutas surpresa : ['maçã', 'banana', 'uva']
